# %%
# !pip install ultralytics opencv-python numpy scipy
# Out:
# Requirement already satisfied: ultralytics in c:\programdata\anaconda3\lib\site-packages (8.3.223)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.15.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: torch>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (1.35.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\programdata\anaconda3\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: polars-runtime-32==1.35.1 in c:\programdata\anaconda3\lib\site-packages (from polars->ultralytics) (1.35.1)

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from collections import deque
from scipy.spatial import distance as dist
from collections import OrderedDict

# %%
import cv2
import numpy as np
from collections import OrderedDict, deque
import time, os
from ultralytics import YOLO

# ==== User Configurations ====
VIDEO_PATH = r"C:\Users\harsh\Downloads\samplevideo.mp4"   # <-- Change to your video path or 0 for webcam"
OUTPUT_PATH = "output.avi"
DISPLAY = True                   # Set False if you don’t want to open video window
COUNT_LINE_POSITION = 0.5        # Line position (as fraction of frame height)
LINE_THICKNESS = 2
MAX_DISAPPEARED = 40
MAX_DISTANCE = 80
HISTORY_LEN = 64

# Ensure old output is removed
if os.path.exists(OUTPUT_PATH):
    os.remove(OUTPUT_PATH)

# %%
class CentroidTracker:
    def _init_(self, maxDisappeared=MAX_DISAPPEARED, maxDistance=MAX_DISTANCE):
        self.nextObjectID = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()
        self.maxDisappeared = maxDisappeared
        self.maxDistance = maxDistance
        self.tracks = {}

    def register(self, centroid):
        self.objects[self.nextObjectID] = centroid
        self.disappeared[self.nextObjectID] = 0
        self.tracks[self.nextObjectID] = deque(maxlen=HISTORY_LEN)
        self.tracks[self.nextObjectID].append(centroid)
        self.nextObjectID += 1

    def deregister(self, objectID):
        if objectID in self.objects: del self.objects[objectID]
        if objectID in self.disappeared: del self.disappeared[objectID]
        if objectID in self.tracks: del self.tracks[objectID]

    def update(self, rects):
        if len(rects) == 0:
            for oid in list(self.disappeared.keys()):
                self.disappeared[oid] += 1
                if self.disappeared[oid] > self.maxDisappeared:
                    self.deregister(oid)
            return self.objects

        inputCentroids = np.zeros((len(rects), 2), dtype="int")
        for (i, (startX, startY, endX, endY)) in enumerate(rects):
            cX, cY = int((startX + endX) / 2.0), int((startY + endY) / 2.0)
            inputCentroids[i] = (cX, cY)

        if len(self.objects) == 0:
            for i in range(0, len(inputCentroids)):
                self.register(tuple(inputCentroids[i]))
        else:
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())
            D = np.linalg.norm(np.array(objectCentroids)[:, np.newaxis] - inputCentroids[np.newaxis, :], axis=2)

            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]
            usedRows, usedCols = set(), set()

            for (row, col) in zip(rows, cols):
                if row in usedRows or col in usedCols: continue
                if D[row, col] > self.maxDistance: continue
                objectID = objectIDs[row]
                self.objects[objectID] = tuple(inputCentroids[col])
                self.tracks[objectID].append(tuple(inputCentroids[col]))
                self.disappeared[objectID] = 0
                usedRows.add(row)
                usedCols.add(col)

            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            for row in unusedRows:
                objectID = objectIDs[row]
                self.disappeared[objectID] += 1
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)
            for col in unusedCols:
                self.register(tuple(inputCentroids[col]))

        return self.objects

# %%
def intersects_line(prev, cur, line_y):
    return (prev[1] < line_y and cur[1] >= line_y) or (prev[1] > line_y and cur[1] <= line_y)

def draw_info(frame, total_in, total_out):
    cv2.putText(frame, f"IN: {total_in}  OUT: {total_out}", (20, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

# %%
# -----------------------------
# Centroid Tracker Class (Fixed)
# -----------------------------
from scipy.spatial import distance as dist
from collections import OrderedDict
import numpy as np

class CentroidTracker:
    def __init__(self, maxDisappeared=50, maxDistance=80):  # ✅ fixed constructor
        self.nextObjectID = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()  # ✅ now properly initialized
        self.maxDisappeared = maxDisappeared
        self.maxDistance = maxDistance  # ✅ optional: distance threshold for better tracking

    def register(self, centroid):
        self.objects[self.nextObjectID] = centroid
        self.disappeared[self.nextObjectID] = 0
        self.nextObjectID += 1

    def deregister(self, objectID):
        del self.objects[objectID]
        del self.disappeared[objectID]

    def update(self, rects):
        # if no detections, mark all objects as disappeared
        if len(rects) == 0:
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)
            return self.objects

        # compute centroids for current frame
        inputCentroids = np.zeros((len(rects), 2), dtype="int")
        for (i, (x1, y1, x2, y2)) in enumerate(rects):
            cX = int((x1 + x2) / 2.0)
            cY = int((y1 + y2) / 2.0)
            inputCentroids[i] = (cX, cY)

        # if no existing objects, register all
        if len(self.objects) == 0:
            for i in range(0, len(inputCentroids)):
                self.register(inputCentroids[i])
        else:
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())

            D = dist.cdist(np.array(objectCentroids), inputCentroids)
            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]

            usedRows, usedCols = set(), set()

            for (row, col) in zip(rows, cols):
                if row in usedRows or col in usedCols:
                    continue
                if D[row, col] > self.maxDistance:  # ✅ optional distance filter
                    continue
                objectID = objectIDs[row]
                self.objects[objectID] = inputCentroids[col]
                self.disappeared[objectID] = 0
                usedRows.add(row)
                usedCols.add(col)

            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            if D.shape[0] >= D.shape[1]:
                for row in unusedRows:
                    objectID = objectIDs[row]
                    self.disappeared[objectID] += 1
                    if self.disappeared[objectID] > self.maxDisappeared:
                        self.deregister(objectID)
            else:
                for col in unusedCols:
                    self.register(inputCentroids[col])

        return self.objects

# %%
def process_video(video_path=VIDEO_PATH, output_path="output.avi"):
    from collections import deque

    model = YOLO("yolov8n.pt")
    ct = CentroidTracker(maxDisappeared=40)
    trackable = {}
    total_in, total_out = 0, 0

    cap = cv2.VideoCapture(video_path)
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"XVID"), fps, (w, h))

    line_y = h // 2  # middle line
    pts = [deque(maxlen=30) for _ in range(9999)]

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model(frame, stream=True)
        rects = []

        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                rects.append((x1, y1, x2, y2))
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        objects = ct.update(rects)

        for (objectID, centroid) in objects.items():
            to = trackable.get(objectID, None)
            if to is None:
                trackable[objectID] = {"centroids": [centroid], "counted": False}
            else:
                trackable[objectID]["centroids"].append(centroid)
                if not to["counted"]:
                    if centroid[1] < line_y and np.mean([c[1] for c in to["centroids"][-5:]]) >= line_y:
                        total_out += 1
                        to["counted"] = True
                    elif centroid[1] > line_y and np.mean([c[1] for c in to["centroids"][-5:]]) <= line_y:
                        total_in += 1
                        to["counted"] = True

            text = f"ID {objectID}"
            cv2.putText(frame, text, (centroid[0] - 10, centroid[1] - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            cv2.circle(frame, (centroid[0], centroid[1]), 4, (0, 255, 0), -1)

        cv2.line(frame, (0, line_y), (w, line_y), (0, 0, 255), 2)
        cv2.putText(frame, f"IN: {total_in}  OUT: {total_out}",
                    (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

        writer.write(frame)

    cap.release()
    writer.release()
    print("✅ Processing complete. Video saved as:", output_path)
    return trackable, {"in": total_in, "out": total_out}

# %%
trackable, counts = process_video()
# Out:
# 0: 384x640 (no detections), 627.7ms
# Speed: 45.8ms preprocess, 627.7ms inference, 46.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 313.3ms
# Speed: 6.6ms preprocess, 313.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 332.1ms
# Speed: 9.5ms preprocess, 332.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 364.8ms
# Speed: 12.9ms preprocess, 364.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 363.4ms
# Speed: 10.4ms preprocess, 363.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 302.4ms
# Speed: 11.5ms preprocess, 302.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 301.1ms
# Speed: 9.8ms preprocess, 301.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.2ms
# Speed: 10.4ms preprocess, 113.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.0ms
# Speed: 2.5ms preprocess, 131.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 221.7ms
# Speed: 8.7ms preprocess, 221.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 383.6ms
# Speed: 7.6ms preprocess, 383.6ms inference, 33.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 503.5ms
# Speed: 23.2ms preprocess, 503.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 267.9ms
# Speed: 3.4ms preprocess, 267.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 309.3ms
# Speed: 4.8ms preprocess, 309.3ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 263.3ms
# Speed: 6.8ms preprocess, 263.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 290.5ms
# Speed: 10.4ms preprocess, 290.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 324.6ms
# Speed: 13.1ms preprocess, 324.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 262.1ms
# Speed: 6.7ms preprocess, 262.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 273.2ms
# Speed: 7.6ms preprocess, 273.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 272.0ms
# Speed: 9.2ms preprocess, 272.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.5ms
# Speed: 19.5ms preprocess, 399.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 316.1ms
# Speed: 9.5ms preprocess, 316.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 605.4ms
# Speed: 12.1ms preprocess, 605.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.5ms
# Speed: 10.9ms preprocess, 407.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person,
4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 handbag, 252.9ms
# Speed: 9.6ms preprocess, 252.9ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 288.3ms
# Speed: 9.0ms preprocess, 288.3ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 306.6ms
# Speed: 12.2ms preprocess, 306.6ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 294.8ms
# Speed: 7.0ms preprocess, 294.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 316.6ms
# Speed: 11.8ms preprocess, 316.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 backpack, 280.2ms
# Speed: 8.8ms preprocess, 280.2ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 backpack, 277.5ms
# Speed: 8.9ms preprocess, 277.5ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 252.7ms
# Speed: 8.4ms preprocess, 252.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 1 skateboard, 248.2ms
# Speed: 7.6ms preprocess, 248.2ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 backpack, 241.8ms
# Speed: 8.3ms preprocess, 241.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 319.6ms
# Speed: 6.0ms preprocess, 319.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 277.8ms
# Speed: 6.1ms preprocess, 277.8ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 1 handbag, 278.2ms
# Speed: 7.2ms preprocess, 278.2ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 backpack, 1 handbag, 312.1ms
# Speed: 9.0ms preprocess, 312.1ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 backpack, 243.4ms
# Speed: 7.5ms preprocess, 243.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 backpack, 1 handbag, 306.9ms
# Speed: 9.4ms preprocess, 306.9ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 296.5ms
# Speed: 8.0ms preprocess, 296.5ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 250.7ms
# Speed: 5.5ms preprocess, 250.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 230.5ms
# Speed: 7.6ms preprocess, 230.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 189.9ms
# Speed: 6.5ms preprocess, 189.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 240.4ms
# Speed: 6.9ms preprocess, 240.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 301.3ms
# Speed: 8.4ms preprocess, 301.3ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 341.4ms
# Speed: 11.9ms preprocess, 341.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 359.5ms
# Speed: 10.1ms preprocess, 359.5ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 backpack, 107.6ms
# Speed: 4.0ms preprocess, 107.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 87.9ms
# Speed: 2.7ms preprocess, 87.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 85.0ms
# Speed: 3.2ms preprocess, 85.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 90.1ms
# Speed: 3.8ms preprocess, 90.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 skateboard, 86.2ms
# Speed: 3.7ms preprocess, 86.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 87.5ms
# Speed: 3.3ms preprocess, 87.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 skateboard, 98.6ms
# Speed: 4.0ms preprocess, 98.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 93.6ms
# Speed: 2.5ms preprocess, 93.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 88.3ms
# Speed: 2.8ms preprocess, 88.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 81.5ms
# Speed: 2.8ms preprocess, 81.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 96.1ms
# Speed: 3.9ms preprocess, 96.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 82.8ms
# Speed: 3.1ms preprocess, 82.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 103.2ms
# Speed: 2.8ms preprocess, 103.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 107.5ms
# Speed: 3.0ms preprocess, 107.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 86.8ms
# Speed: 2.6ms preprocess, 86.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 223.6ms
# Speed: 2.9ms preprocess, 223.6ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 294.2ms
# Speed: 8.4ms preprocess, 294.2ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 234.4ms
# Speed: 7.6ms preprocess, 234.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 226.1ms
# Speed: 7.4ms preprocess, 226.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons,
1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cell phone, 289.0ms
# Speed: 7.3ms preprocess, 289.0ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cell phone, 268.2ms
# Speed: 7.6ms preprocess, 268.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 292.7ms
# Speed: 9.5ms preprocess, 292.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 cell phone, 286.5ms
# Speed: 9.8ms preprocess, 286.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 cell phone, 305.8ms
# Speed: 11.2ms preprocess, 305.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 remote, 288.1ms
# Speed: 8.5ms preprocess, 288.1ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 cell phone, 273.5ms
# Speed: 7.3ms preprocess, 273.5ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 remote, 229.9ms
# Speed: 7.8ms preprocess, 229.9ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 cell phone, 271.7ms
# Speed: 8.3ms preprocess, 271.7ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 cell phone, 295.3ms
# Speed: 8.4ms preprocess, 295.3ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 cell phone, 267.2ms
# Speed: 7.6ms preprocess, 267.2ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 remote, 1 cell phone, 310.5ms
# Speed: 11.0ms preprocess, 310.5ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 remotes, 320.6ms
# Speed: 9.1ms preprocess, 320.6ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 remote, 336.0ms
# Speed: 10.3ms preprocess, 336.0ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 remote, 322.5ms
# Speed: 10.9ms preprocess, 322.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 293.3ms
# Speed: 10.8ms preprocess, 293.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 271.0ms
# Speed: 7.0ms preprocess, 271.0ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 271.9ms
# Speed: 7.1ms preprocess, 271.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 260.4ms
# Speed: 7.1ms preprocess, 260.4ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 270.9ms
# Speed: 7.8ms preprocess, 270.9ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 291.1ms
# Speed: 9.9ms preprocess, 291.1ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 259.4ms
# Speed: 7.0ms preprocess, 259.4ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 269.8ms
# Speed: 7.0ms preprocess, 269.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 283.5ms
# Speed: 8.3ms preprocess, 283.5ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 303.2ms
# Speed: 9.6ms preprocess, 303.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 291.6ms
# Speed: 10.9ms preprocess, 291.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 244.6ms
# Speed: 9.6ms preprocess, 244.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 270.3ms
# Speed: 6.9ms preprocess, 270.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 280.1ms
# Speed: 9.4ms preprocess, 280.1ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 284.9ms
# Speed: 8.7ms preprocess, 284.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 277.4ms
# Speed: 6.5ms preprocess, 277.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 255.1ms
# Speed: 6.9ms preprocess, 255.1ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 290.4ms
# Speed: 8.5ms preprocess, 290.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 272.0ms
# Speed: 8.6ms preprocess, 272.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 279.5ms
# Speed: 8.8ms preprocess, 279.5ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 handbag, 265.6ms
# Speed: 5.8ms preprocess, 265.6ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 229.7ms
# Speed: 6.7ms preprocess, 229.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 253.8ms
# Speed: 6.5ms preprocess, 253.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 1 suitcase, 282.8ms
# Speed: 9.1ms preprocess, 282.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 skateboard, 293.5ms
# Speed: 10.4ms preprocess, 293.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 261.8ms
# Speed: 7.9ms preprocess, 261.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 261.9ms
# Speed: 8.6ms preprocess, 261.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 254.8ms
# Speed: 7.4ms preprocess, 254.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 249.1ms
# Speed: 6.2ms preprocess, 249.1ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 251.0ms
# Speed: 10.0ms preprocess, 251.0ms inference, 35.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processing complete. Video saved as: output.avi

# %%
# Generate Heatmap from tracked centroids
def create_heatmap(trackable, w, h):
    heatmap = np.zeros((h, w), np.float32)
    for obj in trackable.values():
        for (x, y) in obj["centroids"]:
            if 0 <= y < h and 0 <= x < w:
                heatmap[y, x] += 1
    heatmap = cv2.GaussianBlur(heatmap, (0, 0), sigmaX=25, sigmaY=25)
    heatmap = cv2.normalize(heatmap, None, 0, 255, cv2.NORM_MINMAX)
    heatmap = np.uint8(heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    return heatmap


# 🧠 Use the trackable data returned from process_video()
if "trackable" in locals() and trackable:
    cap = cv2.VideoCapture(VIDEO_PATH)
    ret, frame = cap.read()
    if ret:
        h, w = frame.shape[:2]
        heatmap = create_heatmap(trackable, w, h)
        cv2.imwrite("heatmap.png", heatmap)
        print("🔥 Heatmap saved as heatmap.png")
    else:
        print("⚠ Could not read the first frame from video.")
    cap.release()
else:
    print("⚠ Run the cell with 'trackable, counts = process_video()' first.")
# Out:
# 🔥 Heatmap saved as heatmap.png

# %%
import cv2
import numpy as np
import threading
from ultralytics import YOLO
from scipy.spatial import distance as dist
from collections import OrderedDict

# ==========================
# Centroid Tracker Class
# ==========================
class CentroidTracker:
    def __init__(self, maxDisappeared=50, maxDistance=50):
        self.nextObjectID = 0
        self.objects = OrderedDict()
        self.disappeared = OrderedDict()
        self.maxDisappeared = maxDisappeared
        self.maxDistance = maxDistance

    def register(self, centroid):
        self.objects[self.nextObjectID] = centroid
        self.disappeared[self.nextObjectID] = 0
        self.nextObjectID += 1

    def deregister(self, objectID):
        del self.objects[objectID]
        del self.disappeared[objectID]

    def update(self, rects):
        if len(rects) == 0:
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)
            return self.objects

        inputCentroids = np.zeros((len(rects), 2), dtype="int")

        for (i, (x1, y1, x2, y2)) in enumerate(rects):
            cX = int((x1 + x2) / 2.0)
            cY = int((y1 + y2) / 2.0)
            inputCentroids[i] = (cX, cY)

        if len(self.objects) == 0:
            for i in range(len(inputCentroids)):
                self.register(inputCentroids[i])

        else:
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())

            D = dist.cdist(np.array(objectCentroids), inputCentroids)

            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]

            usedRows = set()
            usedCols = set()

            for (row, col) in zip(rows, cols):
                if row in usedRows or col in usedCols:
                    continue
                if D[row, col] > self.maxDistance:
                    continue
                objectID = objectIDs[row]
                self.objects[objectID] = inputCentroids[col]
                self.disappeared[objectID] = 0
                usedRows.add(row)
                usedCols.add(col)

            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            for col in unusedCols:
                self.register(inputCentroids[col])

        return self.objects


# ==========================
# Real-time Footfall Tracker
# ==========================
model = YOLO("yolov8n.pt")
ct_live = CentroidTracker(maxDisappeared=40, maxDistance=80)
trackable_live = {}
total_in_live, total_out_live = 0, 0

cap = cv2.VideoCapture(0)
heat_accum = None

print("🎥 Starting real-time Footfall Counter...")

# ==========================
# Enter-Key Stop Thread
# ==========================
stop_flag = False

def stop_on_enter():
    global stop_flag
    input("🔴 Press ENTER anytime to stop the webcam...\n")
    stop_flag = True

threading.Thread(target=stop_on_enter, daemon=True).start()


while True:
    ret, frame = cap.read()
    if not ret:
        break

    h, w = frame.shape[:2]
    line_y = int(h * 0.5)

    results = model(frame, imgsz=640, verbose=False)[0]

    boxes = []
    for box in results.boxes:
        if int(box.cls[0]) == 0:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            boxes.append((x1, y1, x2, y2))

    objects = ct_live.update(boxes)

    for (objectID, centroid) in objects.items():
        to = trackable_live.get(objectID, None)
        if to is None:
            trackable_live[objectID] = {'counted': False, 'centroids': [centroid]}
            to = trackable_live[objectID]
        else:
            to['centroids'].append(centroid)

        if len(to['centroids']) >= 2 and not to['counted']:
            prev, cur = to['centroids'][-2], to['centroids'][-1]
            if prev[1] < line_y <= cur[1]:
                total_in_live += 1
                to['counted'] = True
            elif prev[1] > line_y >= cur[1]:
                total_out_live += 1
                to['counted'] = True

        for i in range(1, len(to['centroids'])):
            cv2.line(frame, to['centroids'][i-1], to['centroids'][i], (255, 0, 0), 2)

        cv2.circle(frame, centroid, 4, (0, 255, 0), -1)
        cv2.putText(frame, f"ID {objectID}", (centroid[0]-10, centroid[1]-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2)

    if heat_accum is None:
        heat_accum = np.zeros((h, w), dtype=np.float32)

    for obj in trackable_live.values():
        for (x, y) in obj['centroids']:
            if 0 <= x < w and 0 <= y < h:
                heat_accum[y, x] += 1

    cv2.line(frame, (0, line_y), (w, line_y), (0, 0, 255), 2)
    cv2.putText(frame, f"IN: {total_in_live} | OUT: {total_out_live}",
                (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)

    cv2.imshow("🎦 Real-time Footfall Counter", frame)

    # Stop conditions
    if stop_flag:
        print("🛑 Stopping webcam feed...")
        break

    if cv2.waitKey(1) == 27:
        break

cap.release()
cv2.destroyAllWindows()

if heat_accum is not None:
    heatmap = cv2.applyColorMap(cv2.normalize(heat_accum, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8),
                                cv2.COLORMAP_JET)
    cv2.imwrite("real_time_heatmap.png", heatmap)
    print("🔥 Saved Real-time Heatmap: real_time_heatmap.png")

print(f"✅ Final Counts — People IN: {total_in_live}, OUT: {total_out_live}")
# Out:
# 🎥 Starting real-time Footfall Counter...
# 🔴 Press ENTER anytime to stop the webcam...
# 🛑 Stopping webcam feed...
# 🔥 Saved Real-time Heatmap: real_time_heatmap.png
# ✅ Final Counts — People IN: 6, OUT: 3
